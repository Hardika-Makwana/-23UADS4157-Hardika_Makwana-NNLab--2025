# %% [markdown]
# EXPERIMENT 4

# %% [markdown]
# OBJECTIVE : WAP to evaluate the performance of implemented three-layer neural network with variations in activation functions, size of hidden layer, learning rate, batch size and number of epochs.

# %% [markdown]
# 1. Network Architecture : Activation function in hidden layer -->Relu , hidden layer : (256) , learning rate : 0.1 batch size : 10 , epochs : 50
#
# PYTHON IMPLEMENTATION

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Load and preprocess the MNIST dataset
def preprocess(image, label):
    image = tf.cast(image, tf.float32) / 255.0  # Normalize to [0,1]
    image = tf.reshape(image, [-1])  # Flatten to 784
    label = tf.one_hot(label, depth=10)  # Convert to one-hot encoding
    return image, label

# Load dataset and apply preprocessing
mnist_dataset = tfds.load("mnist", split=["train", "test"], as_supervised=True)
train_data = mnist_dataset[0].map(preprocess).shuffle(10000).batch(10)
test_data = mnist_dataset[1].map(preprocess).batch(10)

# Define neural network parameters
input_size = 784
hidden_layer_size = 256
output_size = 10
learning_rate = 0.1
epochs = 50

# Initialize weights and biases
W1 = tf.Variable(tf.random.normal([input_size, hidden_layer_size]))
b1 = tf.Variable(tf.zeros([hidden_layer_size]))
W_out = tf.Variable(tf.random.normal([hidden_layer_size, output_size]))
b_out = tf.Variable(tf.zeros([output_size]))

# Forward pass function
def forward_pass(X):
    hidden_layer = tf.nn.relu(tf.matmul(X, W1) + b1)
    output_layer = tf.matmul(hidden_layer, W_out) + b_out  # No activation (logits)
    return output_layer

# Define loss function
def loss_fn(logits, labels):
    return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))

# Define optimizer
optimizer = tf.optimizers.Adam(learning_rate)

# Training step function
def train_step(X, Y):
    with tf.GradientTape() as tape:
        logits = forward_pass(X)
        loss = loss_fn(logits, Y)
    gradients = tape.gradient(loss, [W1, b1, W_out, b_out])
    optimizer.apply_gradients(zip(gradients, [W1, b1, W_out, b_out]))
    return loss

# Compute accuracy
def compute_accuracy(dataset):
    total_correct = 0
    total_samples = 0
    for X, Y in dataset:
        logits = forward_pass(X)
        correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(Y, 1))
        total_correct += tf.reduce_sum(tf.cast(correct_pred, tf.float32))
        total_samples += X.shape[0]
    return total_correct / total_samples

# Track loss and accuracy
loss_history = []
accuracy_history = []
start_time = time.time()

# Training loop
for epoch in range(epochs):
    avg_loss = 0
    total_batches = 0

    for batch_x, batch_y in train_data:
        loss = train_step(batch_x, batch_y)
        avg_loss += loss
        total_batches += 1

    avg_loss /= total_batches
    train_acc = compute_accuracy(train_data)
    loss_history.append(avg_loss.numpy())
    accuracy_history.append(train_acc.numpy())
    print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}, Training Accuracy: {train_acc:.4f}")

end_time = time.time()
execution_time = end_time - start_time

# Test the model
test_acc = compute_accuracy(test_data)
print(f"Test Accuracy: {test_acc:.4f}")

# Plot Loss Curve
plt.figure(figsize=(10, 5))
plt.plot(loss_history, label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.show()

# Plot Accuracy Curve
plt.figure(figsize=(10, 5))
plt.plot(accuracy_history, label='Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()
plt.show()

# Compute confusion matrix
y_true, y_pred = [], []
for X, Y in test_data:
    logits = forward_pass(X)
    predictions = tf.argmax(logits, axis=1).numpy()
    labels = tf.argmax(Y, axis=1).numpy()
    y_pred.extend(predictions)
    y_true.extend(labels)

conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

print(f"Execution Time: {execution_time:.2f} seconds")
# Out:
# Epoch 1, Loss: 2.4974, Training Accuracy: 0.3136
# Epoch 2, Loss: 2.0604, Training Accuracy: 0.1917
# Epoch 3, Loss: 2.0815, Training Accuracy: 0.2427
# Epoch 4, Loss: 1.9748, Training Accuracy: 0.3075
# Epoch 5, Loss: 1.9860, Training Accuracy: 0.3102
# Epoch 6, Loss: 1.9946, Training Accuracy: 0.2441
# Epoch 7, Loss: 1.9703, Training Accuracy: 0.3074
# Epoch 8, Loss: 1.9586, Training Accuracy: 0.2416
# Epoch 9, Loss: 1.9653, Training Accuracy: 0.2871
# Epoch 10, Loss: 1.9531, Training Accuracy: 0.3085
# Epoch 11, Loss: 2.0220, Training Accuracy: 0.2924
# Epoch 12, Loss: 1.9142, Training Accuracy: 0.3050
# Epoch 13, Loss: 1.9285, Training Accuracy: 0.3312
# Epoch 14, Loss: 1.8961, Training Accuracy: 0.2952
# Epoch 15, Loss: 1.8783, Training Accuracy: 0.2751
# Epoch 16, Loss: 1.8939, Training Accuracy: 0.2921
# Epoch 17, Loss: 1.8655, Training Accuracy: 0.2893
# Epoch 18, Loss: 1.9233, Training Accuracy: 0.3142
# Epoch 19, Loss: 1.9081, Training Accuracy: 0.3307
# Epoch 20, Loss: 1.9351, Training Accuracy: 0.2732
# Epoch 21, Loss: 1.8684, Training Accuracy: 0.2903
# Epoch 22, Loss: 1.8825, Training Accuracy: 0.2864
# Epoch 23, Loss: 1.9255, Training Accuracy: 0.2890
# Epoch 24, Loss: 1.8897, Training Accuracy: 0.2985
# Epoch 25, Loss: 1.9009, Training Accuracy: 0.3274
# Epoch 26, Loss: 1.8711, Training Accuracy: 0.3058
# Epoch 27, Loss: 1.9394, Training Accuracy: 0.2476
# Epoch 28, Loss: 1.8819, Training Accuracy: 0.3169
# Epoch 29, Loss: 1.9238, Training Accuracy: 0.3094
# Epoch 30, Loss: 1.8365, Training Accuracy: 0.3171
# Epoch 31, Loss: 1.9487, Training Accuracy: 0.2970
# Epoch 32, Loss: 1.9808, Training Accuracy: 0.2959
# Epoch 33, Loss: 1.8890, Training Accuracy: 0.3309
# Epoch 34, Loss: 1.9280, Training Accuracy: 0.2949
# Epoch 35, Loss: 1.9471, Training Accuracy: 0.3138
# Epoch 36, Loss: 1.8580, Training Accuracy: 0.3125
# Epoch 37, Loss: 1.8504, Training Accuracy: 0.3061
# Epoch 38, Loss: 1.8643, Training Accuracy: 0.3091
# Epoch 39, Loss: 1.8007, Training Accuracy: 0.3021
# Epoch 40, Loss: 1.8517, Training Accuracy: 0.3255
# Epoch 41, Loss: 1.9250, Training Accuracy: 0.3221
# Epoch 42, Loss: 1.8358, Training Accuracy: 0.3140
# Epoch 43, Loss: 1.8473, Training Accuracy: 0.3137
# Epoch 44, Loss: 1.8951, Training Accuracy: 0.3084
# Epoch 45, Loss: 1.8392, Training Accuracy: 0.3219
# Epoch 46, Loss: 1.8604, Training Accuracy: 0.3047
# Epoch 47, Loss: 1.8388, Training Accuracy: 0.3046
# Epoch 48, Loss: 1.8531, Training Accuracy: 0.3191
# Epoch 49, Loss: 1.9241, Training Accuracy: 0.3145
# Epoch 50, Loss: 1.9294, Training Accuracy: 0.3364
# Test Accuracy: 0.3343
# Execution Time: 10308.36 seconds
