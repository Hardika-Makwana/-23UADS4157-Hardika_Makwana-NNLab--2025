# %%
import numpy as np
class Perceptron:
    def __init__(self, input_size, learning_rate=0.01, epochs=100):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.weights = np.zeros(input_size + 1)  # +1 for bias term
    def activation(self, x):
        return 1 if x >= 0 else 0
    def predict(self, x):
        x = np.insert(x, 0, 1)  # Insert bias term
        return self.activation(np.dot(self.weights, x))
    def train(self, X, y):
        for epoch in range(self.epochs):
            for i in range(len(X)):
                x_i = np.insert(X[i], 0, 1)  # Insert bias term
                prediction = self.activation(np.dot(self.weights, x_i))
                error = y[i] - prediction
                self.weights += self.learning_rate * error * x_i
            print(f"Epoch {epoch + 1}/{self.epochs}, Weights: {self.weights}")
# Example usage
if __name__ == "__main__":
    # AND gate dataset
    X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
    y = np.array([0, 0, 0, 1])
    
    perceptron = Perceptron(input_size=2)
    perceptron.train(X, y)
# Test
for x in X:
  print(f"Input: {x}, Predicted Output: {perceptron.predict(x)}")
# Accuracy Calculation
correct_predictions = 0
for i in range(len(X)):
    prediction = perceptron.predict(X[i])
    print(f"Input: {X[i]}, Predicted Output: {prediction}, Actual Output: {y[i]}")
    if prediction == y[i]:
        correct_predictions += 1
accuracy = (correct_predictions / len(X)) * 100
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# Epoch 1/100, Weights: [0.   0.01 0.01]
# Epoch 2/100, Weights: [-0.01  0.02  0.01]
# Epoch 3/100, Weights: [-0.02  0.02  0.01]
# Epoch 4/100, Weights: [-0.02  0.02  0.02]
# Epoch 5/100, Weights: [-0.03  0.02  0.01]
# Epoch 6/100, Weights: [-0.03  0.02  0.01]
# Epoch 7/100, Weights: [-0.03  0.02  0.01]
# Epoch 8/100, Weights: [-0.03  0.02  0.01]
# Epoch 9/100, Weights: [-0.03  0.02  0.01]
# Epoch 10/100, Weights: [-0.03  0.02  0.01]
# Epoch 11/100, Weights: [-0.03  0.02  0.01]
# Epoch 12/100, Weights: [-0.03  0.02  0.01]
# Epoch 13/100, Weights: [-0.03  0.02  0.01]
# Epoch 14/100, Weights: [-0.03  0.02  0.01]
# Epoch 15/100, Weights: [-0.03  0.02  0.01]
# Epoch 16/100, Weights: [-0.03  0.02  0.01]
# Epoch 17/100, Weights: [-0.03  0.02  0.01]
# Epoch 18/100, Weights: [-0.03  0.02  0.01]
# Epoch 19/100, Weights: [-0.03  0.02  0.01]
# Epoch 20/100, Weights: [-0.03  0.02  0.01]
# Epoch 21/100, Weights: [-0.03  0.02  0.01]
# Epoch 22/100, Weights: [-0.03  0.02  0.01]
# Epoch 23/100, Weights: [-0.03  0.02  0.01]
# Epoch 24/100, Weights: [-0.03  0.02  0.01]
# Epoch 25/100, Weights: [-0.03  0.02  0.01]
# Epoch 26/100, Weights: [-0.03  0.02  0.01]
# Epoch 27/100, Weights: [-0.03  0.02  0.01]
# Epoch 28/100, Weights: [-0.03  0.02  0.01]
# Epoch 29/100, Weights: [-0.03  0.02  0.01]
# Epoch 30/100, Weights: [-0.03  0.02  0.01]
# Epoch 31/100, Weights: [-0.03  0.02  0.01]
# Epoch 32/100, Weights: [-0.03  0.02  0.01]
# Epoch 33/100, Weights: [-0.03  0.02  0.01]
# Epoch 34/100, Weights: [-0.03  0.02  0.01]
# Epoch 35/100, Weights: [-0.03  0.02  0.01]
# Epoch 36/100, Weights: [-0.03  0.02  0.01]
# Epoch 37/100, Weights: [-0.03  0.02  0.01]
# Epoch 38/100, Weights: [-0.03  0.02  0.01]
# Epoch 39/100, Weights: [-0.03  0.02  0.01]
# Epoch 40/100, Weights: [-0.03  0.02  0.01]
# Epoch 41/100, Weights: [-0.03  0.02  0.01]
# Epoch 42/100, Weights: [-0.03  0.02  0.01]
# Epoch 43/100, Weights: [-0.03  0.02  0.01]
# Epoch 44/100, Weights: [-0.03  0.02  0.01]
# Epoch 45/100, Weights: [-0.03  0.02  0.01]
# Epoch 46/100, Weights: [-0.03  0.02  0.01]
# Epoch 47/100, Weights: [-0.03  0.02  0.01]
# Epoch 48/100, Weights: [-0.03  0.02  0.01]
# Epoch 49/100, Weights: [-0.03  0.02  0.01]
# Epoch 50/100, Weights: [-0.03  0.02  0.01]
# Epoch 51/100, Weights: [-0.03  0.02  0.01]
# Epoch 52/100, Weights: [-0.03  0.02  0.01]
# Epoch 53/100, Weights: [-0.03  0.02  0.01]
# Epoch 54/100, Weights: [-0.03  0.02  0.01]
# Epoch 55/100, Weights: [-0.03  0.02  0.01]
# Epoch 56/100, Weights: [-0.03  0.02  0.01]
# Epoch 57/100, Weights: [-0.03  0.02  0.01]
# Epoch 58/100, Weights: [-0.03  0.02  0.01]
# Epoch 59/100, Weights: [-0.03  0.02  0.01]
# Epoch 60/100, Weights: [-0.03  0.02  0.01]
# Epoch 61/100, Weights: [-0.03  0.02  0.01]
# Epoch 62/100, Weights: [-0.03  0.02  0.01]
# Epoch 63/100, Weights: [-0.03  0.02  0.01]
# Epoch 64/100, Weights: [-0.03  0.02  0.01]
# Epoch 65/100, Weights: [-0.03  0.02  0.01]
# Epoch 66/100, Weights: [-0.03  0.02  0.01]
# Epoch 67/100, Weights: [-0.03  0.02  0.01]
# Epoch 68/100, Weights: [-0.03  0.02  0.01]
# Epoch 69/100, Weights: [-0.03  0.02  0.01]
# Epoch 70/100, Weights: [-0.03  0.02  0.01]
# Epoch 71/100, Weights: [-0.03  0.02  0.01]
# Epoch 72/100, Weights: [-0.03  0.02  0.01]
# Epoch 73/100, Weights: [-0.03  0.02  0.01]
# Epoch 74/100, Weights: [-0.03  0.02  0.01]
# Epoch 75/100, Weights: [-0.03  0.02  0.01]
# Epoch 76/100, Weights: [-0.03  0.02  0.01]
# Epoch 77/100, Weights: [-0.03  0.02  0.01]
# Epoch 78/100, Weights: [-0.03  0.02  0.01]
# Epoch 79/100, Weights: [-0.03  0.02  0.01]
# Epoch 80/100, Weights: [-0.03  0.02  0.01]
# Epoch 81/100, Weights: [-0.03  0.02  0.01]
# Epoch 82/100, Weights: [-0.03  0.02  0.01]
# Epoch 83/100, Weights: [-0.03  0.02  0.01]
# Epoch 84/100, Weights: [-0.03  0.02  0.01]
# Epoch 85/100, Weights: [-0.03  0.02  0.01]
# Epoch 86/100, Weights: [-0.03  0.02  0.01]
# Epoch 87/100, Weights: [-0.03  0.02  0.01]
# Epoch 88/100, Weights: [-0.03  0.02  0.01]
# Epoch 89/100, Weights: [-0.03  0.02  0.01]
# Epoch 90/100, Weights: [-0.03  0.02  0.01]
# Epoch 91/100, Weights: [-0.03  0.02  0.01]
# Epoch 92/100, Weights: [-0.03  0.02  0.01]
# Epoch 93/100, Weights: [-0.03  0.02  0.01]
# Epoch 94/100, Weights: [-0.03  0.02  0.01]
# Epoch 95/100, Weights: [-0.03  0.02  0.01]
# Epoch 96/100, Weights: [-0.03  0.02  0.01]
# Epoch 97/100, Weights: [-0.03  0.02  0.01]
# Epoch 98/100, Weights: [-0.03  0.02  0.01]
# Epoch 99/100, Weights: [-0.03  0.02  0.01]
# Epoch 100/100, Weights: [-0.03  0.02  0.01]
# Input: [0 0], Predicted Output: 0
# Input: [0 1], Predicted Output: 0
# Input: [1 0], Predicted Output: 0
# Input: [1 1], Predicted Output: 1
# Input: [0 0], Predicted Output: 0, Actual Output: 0
# Input: [0 1], Predicted Output: 0, Actual Output: 0
# Input: [1 0], Predicted Output: 0, Actual Output: 0
# Input: [1 1], Predicted Output: 1, Actual Output: 1
# Accuracy: 100.00%
