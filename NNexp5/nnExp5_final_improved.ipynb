# %%
"""EXPERIMENT 5"""

# %%
"""5 conv layers : Cases for optimisers [Adam , SGD with momentum] , batch sizes[ 64 ,128]"""
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# Load Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Normalize images to [0,1] range
x_train, x_test = x_train / 255.0, x_test / 255.0

# Reshape for CNN (Adding channel dimension)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Function to create the CNN model
def create_model():
    model = keras.Sequential([
        layers.Conv2D(32, (3,3), padding='same', activation=None, input_shape=(28,28,1)),
        layers.Activation('relu'),
        layers.BatchNormalization(),

        layers.Conv2D(32, (3,3), padding='same', activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.2),

        layers.Conv2D(64, (3,3), padding='same', activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),

        layers.Conv2D(64, (3,3), padding='same', activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.2),

        layers.Conv2D(128, (3,3), padding='same', activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.2),

        layers.Flatten(),
        layers.Dense(512, activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.2),

        layers.Dense(10, activation='softmax')
    ])
    return model

# Define hyperparameter cases
cases = [
    (keras.optimizers.Adam(learning_rate=0.0005), 64, "Adam, Batch 64"),
    (keras.optimizers.Adam(learning_rate=0.0005), 128, "Adam, Batch 128"),
    (keras.optimizers.SGD(learning_rate=0.01, momentum=0.9), 64, "SGD w/ Momentum, Batch 64"),
    (keras.optimizers.SGD(learning_rate=0.01, momentum=0.9), 128, "SGD w/ Momentum, Batch 128")
]

# Training and evaluation for each case
for optimizer, batch_size, case_name in cases:
    print(f"\n{'='*20}\nTraining Case: {case_name}\n{'='*20}")

    model = create_model()
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    history = model.fit(x_train, y_train, epochs=18, batch_size=batch_size, validation_data=(x_test, y_test))

    test_loss, test_acc = model.evaluate(x_test, y_test)
    print(f"Test Accuracy ({case_name}): {test_acc:.4f}\n")

    # Plot Accuracy & Loss Curves
    plt.figure(figsize=(12,5))

    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title(f'Accuracy Curve - {case_name}')
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'Loss Curve - {case_name}')
    plt.legend()

    plt.show()

    # Confusion Matrix
    y_pred = np.argmax(model.predict(x_test), axis=1)
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title(f'Confusion Matrix - {case_name}')
    plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# ====================
# Training Case: Adam, Batch 64
# ====================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.7634 - loss: 0.6883 - val_accuracy: 0.8603 - val_loss: 0.3995
# Epoch 2/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - accuracy: 0.8732 - loss: 0.3485 - val_accuracy: 0.8842 - val_loss: 0.3072
# Epoch 3/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9007 - loss: 0.2724 - val_accuracy: 0.9095 - val_loss: 0.2455
# Epoch 4/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9105 - loss: 0.2443 - val_accuracy: 0.8781 - val_loss: 0.3401
# Epoch 5/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9145 - loss: 0.2284 - val_accuracy: 0.9122 - val_loss: 0.2303
# Epoch 6/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9230 - loss: 0.2082 - val_accuracy: 0.9184 - val_loss: 0.2216
# Epoch 7/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9295 - loss: 0.1912 - val_accuracy: 0.9209 - val_loss: 0.2144
# Epoch 8/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9347 - loss: 0.1776 - val_accuracy: 0.8993 - val_loss: 0.2904
# Epoch 9/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9369 - loss: 0.1672 - val_accuracy: 0.9312 - val_loss: 0.1970
# Epoch 10/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9416 - loss: 0.1591 - val_accuracy: 0.9334 - val_loss: 0.1889
# Epoch 11/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9454 - loss: 0.1478 - val_accuracy: 0.9274 - val_loss: 0.2033
# Epoch 12/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9456 - loss: 0.1430 - val_accuracy: 0.9287 - val_loss: 0.2069
# Epoch 13/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9481 - loss: 0.1362 - val_accuracy: 0.9287 - val_loss: 0.1989
# Epoch 14/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9530 - loss: 0.1244 - val_accuracy: 0.9340 - val_loss: 0.1884
# Epoch 15/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9520 - loss: 0.1229 - val_accuracy: 0.9298 - val_loss: 0.2137
# Epoch 16/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9569 - loss: 0.1166 - val_accuracy: 0.9384 - val_loss: 0.1880
# Epoch 17/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9596 - loss: 0.1098 - val_accuracy: 0.9368 - val_loss: 0.1892
# Epoch 18/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9620 - loss: 0.1023 - val_accuracy: 0.9344 - val_loss: 0.1946
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9332 - loss: 0.2017
# Test Accuracy (Adam, Batch 64): 0.9344
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# ====================
# Training Case: Adam, Batch 128
# ====================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 28ms/step - accuracy: 0.7478 - loss: 0.7421 - val_accuracy: 0.6115 - val_loss: 1.1952
# Epoch 2/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8747 - loss: 0.3467 - val_accuracy: 0.8991 - val_loss: 0.2746
# Epoch 3/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.8978 - loss: 0.2803 - val_accuracy: 0.8982 - val_loss: 0.2778
# Epoch 4/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9082 - loss: 0.2491 - val_accuracy: 0.9113 - val_loss: 0.2461
# Epoch 5/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9188 - loss: 0.2251 - val_accuracy: 0.9167 - val_loss: 0.2334
# Epoch 6/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9243 - loss: 0.2059 - val_accuracy: 0.9227 - val_loss: 0.2157
# Epoch 7/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9267 - loss: 0.1961 - val_accuracy: 0.9108 - val_loss: 0.2311
# Epoch 8/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9310 - loss: 0.1836 - val_accuracy: 0.9181 - val_loss: 0.2281
# Epoch 9/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9357 - loss: 0.1742 - val_accuracy: 0.9290 - val_loss: 0.1996
# Epoch 10/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9384 - loss: 0.1676 - val_accuracy: 0.9126 - val_loss: 0.2388
# Epoch 11/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9428 - loss: 0.1577 - val_accuracy: 0.9292 - val_loss: 0.1970
# Epoch 12/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9405 - loss: 0.1560 - val_accuracy: 0.9300 - val_loss: 0.1939
# Epoch 13/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9461 - loss: 0.1441 - val_accuracy: 0.9254 - val_loss: 0.2187
# Epoch 14/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9498 - loss: 0.1351 - val_accuracy: 0.9297 - val_loss: 0.1988
# Epoch 15/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9513 - loss: 0.1300 - val_accuracy: 0.9303 - val_loss: 0.1952
# Epoch 16/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9549 - loss: 0.1204 - val_accuracy: 0.9298 - val_loss: 0.2110
# Epoch 17/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9564 - loss: 0.1163 - val_accuracy: 0.9309 - val_loss: 0.2081
# Epoch 18/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9585 - loss: 0.1099 - val_accuracy: 0.9312 - val_loss: 0.2042
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9306 - loss: 0.2040
# Test Accuracy (Adam, Batch 128): 0.9312
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# ====================
# Training Case: SGD w/ Momentum, Batch 64
# ====================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.7707 - loss: 0.6577 - val_accuracy: 0.8731 - val_loss: 0.3377
# Epoch 2/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8822 - loss: 0.3210 - val_accuracy: 0.8736 - val_loss: 0.3465
# Epoch 3/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8990 - loss: 0.2754 - val_accuracy: 0.9104 - val_loss: 0.2454
# Epoch 4/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9069 - loss: 0.2494 - val_accuracy: 0.9164 - val_loss: 0.2298
# Epoch 5/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9170 - loss: 0.2280 - val_accuracy: 0.9146 - val_loss: 0.2291
# Epoch 6/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9192 - loss: 0.2180 - val_accuracy: 0.9124 - val_loss: 0.2388
# Epoch 7/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9231 - loss: 0.2080 - val_accuracy: 0.9245 - val_loss: 0.2080
# Epoch 8/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9255 - loss: 0.2002 - val_accuracy: 0.9260 - val_loss: 0.2045
# Epoch 9/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9315 - loss: 0.1866 - val_accuracy: 0.9252 - val_loss: 0.2016
# Epoch 10/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9329 - loss: 0.1804 - val_accuracy: 0.9261 - val_loss: 0.2034
# Epoch 11/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9377 - loss: 0.1682 - val_accuracy: 0.9144 - val_loss: 0.2327
# Epoch 12/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9388 - loss: 0.1643 - val_accuracy: 0.9263 - val_loss: 0.1991
# Epoch 13/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9383 - loss: 0.1621 - val_accuracy: 0.9241 - val_loss: 0.2067
# Epoch 14/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9420 - loss: 0.1556 - val_accuracy: 0.9302 - val_loss: 0.1978
# Epoch 15/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9436 - loss: 0.1525 - val_accuracy: 0.9283 - val_loss: 0.2003
# Epoch 16/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9446 - loss: 0.1471 - val_accuracy: 0.9324 - val_loss: 0.1990
# Epoch 17/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9474 - loss: 0.1419 - val_accuracy: 0.9329 - val_loss: 0.1975
# Epoch 18/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9504 - loss: 0.1342 - val_accuracy: 0.9334 - val_loss: 0.1968
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9350 - loss: 0.1969
# Test Accuracy (SGD w/ Momentum, Batch 64): 0.9334
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# ====================
# Training Case: SGD w/ Momentum, Batch 128
# ====================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.7464 - loss: 0.7276 - val_accuracy: 0.7392 - val_loss: 0.7075
# Epoch 2/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8726 - loss: 0.3446 - val_accuracy: 0.8867 - val_loss: 0.2991
# Epoch 3/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.8927 - loss: 0.2937 - val_accuracy: 0.8708 - val_loss: 0.3611
# Epoch 4/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9030 - loss: 0.2620 - val_accuracy: 0.9012 - val_loss: 0.2773
# Epoch 5/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9106 - loss: 0.2418 - val_accuracy: 0.9081 - val_loss: 0.2527
# Epoch 6/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9138 - loss: 0.2296 - val_accuracy: 0.8989 - val_loss: 0.2663
# Epoch 7/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9203 - loss: 0.2168 - val_accuracy: 0.9160 - val_loss: 0.2311
# Epoch 8/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9209 - loss: 0.2145 - val_accuracy: 0.9004 - val_loss: 0.2762
# Epoch 9/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9245 - loss: 0.2006 - val_accuracy: 0.9220 - val_loss: 0.2212
# Epoch 10/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9305 - loss: 0.1872 - val_accuracy: 0.9217 - val_loss: 0.2204
# Epoch 11/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9326 - loss: 0.1818 - val_accuracy: 0.9207 - val_loss: 0.2161
# Epoch 12/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9344 - loss: 0.1764 - val_accuracy: 0.9178 - val_loss: 0.2310
# Epoch 13/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9366 - loss: 0.1704 - val_accuracy: 0.9158 - val_loss: 0.2336
# Epoch 14/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9413 - loss: 0.1615 - val_accuracy: 0.9269 - val_loss: 0.2042
# Epoch 15/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9407 - loss: 0.1589 - val_accuracy: 0.9312 - val_loss: 0.1945
# Epoch 16/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9414 - loss: 0.1593 - val_accuracy: 0.9240 - val_loss: 0.2144
# Epoch 17/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9437 - loss: 0.1538 - val_accuracy: 0.9291 - val_loss: 0.1983
# Epoch 18/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9438 - loss: 0.1485 - val_accuracy: 0.9255 - val_loss: 0.2134
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9278 - loss: 0.2214
# Test Accuracy (SGD w/ Momentum, Batch 128): 0.9255
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
"""8 conv layers 25 epochs : train accuracy - 94.31 , test accuracy - 92.60
55 : train accuracy - 96.64 ,test accuracy - 93.89 
70 : train accuracy - 97.16 , test accuracy - 94.26
90 : train accuracy - 97.84 , test accuracy - 94.46"""
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Load Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Normalize images to [0,1] range
x_train, x_test = x_train / 255.0, x_test / 255.0

# Reshape for CNN (Adding channel dimension)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# CNN Model with deeper architecture
model = keras.Sequential([
    layers.Conv2D(32, (3,3), padding='same', activation=None, input_shape=(28,28,1)),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.Conv2D(32, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.3),

    layers.Conv2D(64, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.Conv2D(64, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.3),

    layers.Conv2D(128, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.Conv2D(128, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.4),

    layers.Conv2D(256, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.Conv2D(256, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.GlobalAveragePooling2D(),

    layers.Dense(512, activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.4),

    layers.Dense(10, activation='softmax')
])

# Compile the model with reduced learning rate
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0003),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model with increased batch size
history = model.fit(x_train, y_train, epochs=90, batch_size=128, validation_data=(x_test, y_test))

# Evaluate test accuracy
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")

# Plot Accuracy & Loss Curves
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 37ms/step - accuracy: 0.6119 - loss: 1.0679 - val_accuracy: 0.3716 - val_loss: 1.8428
# Epoch 2/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8211 - loss: 0.4758 - val_accuracy: 0.8649 - val_loss: 0.3769
# Epoch 3/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8624 - loss: 0.3746 - val_accuracy: 0.8786 - val_loss: 0.3400
# Epoch 4/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8778 - loss: 0.3258 - val_accuracy: 0.8971 - val_loss: 0.2907
# Epoch 5/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8909 - loss: 0.2988 - val_accuracy: 0.9063 - val_loss: 0.2621
# Epoch 6/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8959 - loss: 0.2777 - val_accuracy: 0.9049 - val_loss: 0.2641
# Epoch 7/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9019 - loss: 0.2589 - val_accuracy: 0.9113 - val_loss: 0.2426
# Epoch 8/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9105 - loss: 0.2439 - val_accuracy: 0.9140 - val_loss: 0.2328
# Epoch 9/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9118 - loss: 0.2382 - val_accuracy: 0.9158 - val_loss: 0.2410
# Epoch 10/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9168 - loss: 0.2251 - val_accuracy: 0.9201 - val_loss: 0.2209
# Epoch 11/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9196 - loss: 0.2181 - val_accuracy: 0.9226 - val_loss: 0.2199
# Epoch 12/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.
90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9759 - loss: 0.0637 - val_accuracy: 0.9416 - val_loss: 0.2197
# Epoch 78/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9751 - loss: 0.0658 - val_accuracy: 0.9400 - val_loss: 0.2175
# Epoch 79/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.9762 - loss: 0.0632 - val_accuracy: 0.9397 - val_loss: 0.2152
# Epoch 80/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9756 - loss: 0.0640 - val_accuracy: 0.9414 - val_loss: 0.2195
# Epoch 81/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9773 - loss: 0.0610 - val_accuracy: 0.9403 - val_loss: 0.2411
# Epoch 82/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9759 - loss: 0.0633 - val_accuracy: 0.9411 - val_loss: 0.2207
# Epoch 83/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9760 - loss: 0.0643 - val_accuracy: 0.9402 - val_loss: 0.2353
# Epoch 84/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9772 - loss: 0.0590 - val_accuracy: 0.9409 - val_loss: 0.2341
# Epoch 85/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9762 - loss: 0.0611 - val_accuracy: 0.9388 - val_loss: 0.2375
# Epoch 86/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9769 - loss: 0.0597 - val_accuracy: 0.9397 - val_loss: 0.2332
# Epoch 87/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9780 - loss: 0.0600 - val_accuracy: 0.9426 - val_loss: 0.2232
# Epoch 88/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9762 - loss: 0.0610 - val_accuracy: 0.9409 - val_loss: 0.2343
# Epoch 89/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9781 - loss: 0.0600 - val_accuracy: 0.9409 - val_loss: 0.2475
# Epoch 90/90
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9784 - loss: 0.0561 - val_accuracy: 0.9446 - val_loss: 0.2277
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9432 - loss: 0.2290
# Test Accuracy: 0.9446

# %%
"""8 conv layers 35 epochs: : train accuracy -95.40 , : test accuracy - 93.77 """
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Load Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Normalize images to [0,1] range
x_train, x_test = x_train / 255.0, x_test / 255.0

# Reshape for CNN (Adding channel dimension)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# CNN Model with deeper architecture
model = keras.Sequential([
    layers.Conv2D(32, (3,3), padding='same', activation=None, input_shape=(28,28,1)),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.Conv2D(32, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.3),

    layers.Conv2D(64, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.Conv2D(64, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.3),

    layers.Conv2D(128, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.Conv2D(128, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.4),

    layers.Conv2D(256, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.Conv2D(256, (3,3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),

    layers.GlobalAveragePooling2D(),

    layers.Dense(512, activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.4),

    layers.Dense(10, activation='softmax')
])

# Compile the model with reduced learning rate
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0003),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model with increased batch size
history = model.fit(x_train, y_train, epochs=35, batch_size=128, validation_data=(x_test, y_test))

# Evaluate test accuracy
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")

# Plot Accuracy & Loss Curves
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 36ms/step - accuracy: 0.6214 - loss: 1.0415 - val_accuracy: 0.3347 - val_loss: 2.2590
# Epoch 2/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - accuracy: 0.8278 - loss: 0.4626 - val_accuracy: 0.8662 - val_loss: 0.3654
# Epoch 3/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8601 - loss: 0.3743 - val_accuracy: 0.8799 - val_loss: 0.3222
# Epoch 4/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8799 - loss: 0.3245 - val_accuracy: 0.8870 - val_loss: 0.3082
# Epoch 5/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.8905 - loss: 0.3031 - val_accuracy: 0.9012 - val_loss: 0.2642
# Epoch 6/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8960 - loss: 0.2840 - val_accuracy: 0.9065 - val_loss: 0.2549
# Epoch 7/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9027 - loss: 0.2649 - val_accuracy: 0.9144 - val_loss: 0.2397
# Epoch 8/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9075 - loss: 0.2490 - val_accuracy: 0.9138 - val_loss: 0.2376
# Epoch 9/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9118 - loss: 0.2393 - val_accuracy: 0.9128 - val_loss: 0.2384
# Epoch 10/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9159 - loss: 0.2295 - val_accuracy: 0.9169 - val_loss: 0.2274
# Epoch 11/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9171 - loss: 0.2255 - val_accuracy: 0.9197 - val_loss: 0.2254
# Epoch 12/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9180 - loss: 0.2195 - val_accuracy: 0.9177 - val_loss: 0.2274
# Epoch 13/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.9229 - loss: 0.2103 - val_accuracy: 0.9130 - val_loss: 0.2387
# Epoch 14/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9257 - loss: 0.1997 - val_accuracy: 0.9188 - val_loss: 0.2191
# Epoch 15/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9271 - loss: 0.1968 - val_accuracy: 0.9246 - val_loss: 0.2016
# Epoch 16/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9267 - loss: 0.1991 - val_accuracy: 0.9262 - val_loss: 0.2055
# Epoch 17/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9334 - loss: 0.1838 - val_accuracy: 0.9253 - val_loss: 0.2005
# Epoch 18/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9327 - loss: 0.1804 - val_accuracy: 0.9285 - val_loss: 0.2034
# Epoch 19/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9350 - loss: 0.1779 - val_accuracy: 0.9263 - val_loss: 0.2062
# Epoch 20/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9360 - loss: 0.1748 - val_accuracy: 0.9311 - val_loss: 0.1976
# Epoch 21/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9356 - loss: 0.1703 - val_accuracy: 0.9345 - val_loss: 0.1935
# Epoch 22/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9379 - loss: 0.1659 - val_accuracy: 0.9323 - val_loss: 0.1926
# Epoch 23/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9412 - loss: 0.1616 - val_accuracy: 0.9330 - val_loss: 0.1872
# Epoch 24/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9410 - loss: 0.1571 - val_accuracy: 0.9295 - val_loss: 0.2032
# Epoch 25/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9421 - loss: 0.1536 - val_accuracy: 0.9355 - val_loss: 0.1860
# Epoch 26/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9436 - loss: 0.1498 - val_accuracy: 0.9339 - val_loss: 0.1930
# Epoch 27/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9449 - loss: 0.1461 - val_accuracy: 0.9383 - val_loss: 0.1888
# Epoch 28/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9468 - loss: 0.1426 - val_accuracy: 0.9372 - val_loss: 0.1814
# Epoch 29/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9472 - loss: 0.1432 - val_accuracy: 0.9368 - val_loss: 0.1929
# Epoch 30/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9474 - loss: 0.1386 - val_accuracy: 0.9345 - val_loss: 0.1853
# Epoch 31/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9475 - loss: 0.1435 - val_accuracy: 0.9367 - val_loss: 0.1875
# Epoch 32/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9491 - loss: 0.1329 - val_accuracy: 0.9327 - val_loss: 0.2041
# Epoch 33/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9514 - loss: 0.1291 - val_accuracy: 0.9384 - val_loss: 0.1976
# Epoch 34/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9538 - loss: 0.1249 - val_accuracy: 0.9370 - val_loss: 0.1907
# Epoch 35/35
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9540 - loss: 0.1248 - val_accuracy: 0.9377 - val_loss: 0.1973
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9368 - loss: 0.1999
# Test Accuracy: 0.9377
