# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# Load Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Normalize images to [0,1] range
x_train, x_test = x_train / 255.0, x_test / 255.0

# Reshape for CNN (Adding channel dimension)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Function to create the CNN model
def create_model():
    model = keras.Sequential([
        layers.Conv2D(32, (3,3), padding='same', activation=None, input_shape=(28,28,1)),
        layers.Activation('relu'),
        layers.BatchNormalization(),

        layers.Conv2D(32, (3,3), padding='same', activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.2),

        layers.Conv2D(64, (3,3), padding='same', activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),

        layers.Conv2D(64, (3,3), padding='same', activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.2),

        layers.Conv2D(128, (3,3), padding='same', activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.2),

        layers.Flatten(),
        layers.Dense(512, activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.2),

        layers.Dense(10, activation='softmax')
    ])
    return model

# Define hyperparameter cases
cases = [
    (keras.optimizers.Adam(learning_rate=0.0005), 64, "Adam, Batch 64"),
    (keras.optimizers.Adam(learning_rate=0.0005), 128, "Adam, Batch 128"),
    (keras.optimizers.SGD(learning_rate=0.01, momentum=0.9), 64, "SGD w/ Momentum, Batch 64"),
    (keras.optimizers.SGD(learning_rate=0.01, momentum=0.9), 128, "SGD w/ Momentum, Batch 128")
]

# Training and evaluation for each case
for optimizer, batch_size, case_name in cases:
    print(f"\n{'='*20}\nTraining Case: {case_name}\n{'='*20}")

    model = create_model()
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    history = model.fit(x_train, y_train, epochs=18, batch_size=batch_size, validation_data=(x_test, y_test))

    test_loss, test_acc = model.evaluate(x_test, y_test)
    print(f"Test Accuracy ({case_name}): {test_acc:.4f}\n")

    # Plot Accuracy & Loss Curves
    plt.figure(figsize=(12,5))

    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title(f'Accuracy Curve - {case_name}')
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'Loss Curve - {case_name}')
    plt.legend()

    plt.show()

    # Confusion Matrix
    y_pred = np.argmax(model.predict(x_test), axis=1)
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(5,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title(f'Confusion Matrix - {case_name}')
    plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# ====================
# Training Case: Adam, Batch 64
# ====================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 33s 19ms/step - accuracy: 0.7634 - loss: 0.6883 - val_accuracy: 0.8603 - val_loss: 0.3995
# Epoch 2/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - accuracy: 0.8732 - loss: 0.3485 - val_accuracy: 0.8842 - val_loss: 0.3072
# Epoch 3/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9007 - loss: 0.2724 - val_accuracy: 0.9095 - val_loss: 0.2455
# Epoch 4/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9105 - loss: 0.2443 - val_accuracy: 0.8781 - val_loss: 0.3401
# Epoch 5/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9145 - loss: 0.2284 - val_accuracy: 0.9122 - val_loss: 0.2303
# Epoch 6/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9230 - loss: 0.2082 - val_accuracy: 0.9184 - val_loss: 0.2216
# Epoch 7/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9295 - loss: 0.1912 - val_accuracy: 0.9209 - val_loss: 0.2144
# Epoch 8/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9347 - loss: 0.1776 - val_accuracy: 0.8993 - val_loss: 0.2904
# Epoch 9/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9369 - loss: 0.1672 - val_accuracy: 0.9312 - val_loss: 0.1970
# Epoch 10/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9416 - loss: 0.1591 - val_accuracy: 0.9334 - val_loss: 0.1889
# Epoch 11/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9454 - loss: 0.1478 - val_accuracy: 0.9274 - val_loss: 0.2033
# Epoch 12/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9456 - loss: 0.1430 - val_accuracy: 0.9287 - val_loss: 0.2069
# Epoch 13/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9481 - loss: 0.1362 - val_accuracy: 0.9287 - val_loss: 0.1989
# Epoch 14/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9530 - loss: 0.1244 - val_accuracy: 0.9340 - val_loss: 0.1884
# Epoch 15/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9520 - loss: 0.1229 - val_accuracy: 0.9298 - val_loss: 0.2137
# Epoch 16/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9569 - loss: 0.1166 - val_accuracy: 0.9384 - val_loss: 0.1880
# Epoch 17/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9596 - loss: 0.1098 - val_accuracy: 0.9368 - val_loss: 0.1892
# Epoch 18/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9620 - loss: 0.1023 - val_accuracy: 0.9344 - val_loss: 0.1946
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9332 - loss: 0.2017
# Test Accuracy (Adam, Batch 64): 0.9344
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# ====================
# Training Case: Adam, Batch 128
# ====================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 28ms/step - accuracy: 0.7478 - loss: 0.7421 - val_accuracy: 0.6115 - val_loss: 1.1952
# Epoch 2/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8747 - loss: 0.3467 - val_accuracy: 0.8991 - val_loss: 0.2746
# Epoch 3/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.8978 - loss: 0.2803 - val_accuracy: 0.8982 - val_loss: 0.2778
# Epoch 4/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9082 - loss: 0.2491 - val_accuracy: 0.9113 - val_loss: 0.2461
# Epoch 5/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9188 - loss: 0.2251 - val_accuracy: 0.9167 - val_loss: 0.2334
# Epoch 6/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9243 - loss: 0.2059 - val_accuracy: 0.9227 - val_loss: 0.2157
# Epoch 7/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9267 - loss: 0.1961 - val_accuracy: 0.9108 - val_loss: 0.2311
# Epoch 8/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9310 - loss: 0.1836 - val_accuracy: 0.9181 - val_loss: 0.2281
# Epoch 9/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9357 - loss: 0.1742 - val_accuracy: 0.9290 - val_loss: 0.1996
# Epoch 10/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9384 - loss: 0.1676 - val_accuracy: 0.9126 - val_loss: 0.2388
# Epoch 11/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9428 - loss: 0.1577 - val_accuracy: 0.9292 - val_loss: 0.1970
# Epoch 12/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9405 - loss: 0.1560 - val_accuracy: 0.9300 - val_loss: 0.1939
# Epoch 13/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9461 - loss: 0.1441 - val_accuracy: 0.9254 - val_loss: 0.2187
# Epoch 14/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9498 - loss: 0.1351 - val_accuracy: 0.9297 - val_loss: 0.1988
# Epoch 15/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9513 - loss: 0.1300 - val_accuracy: 0.9303 - val_loss: 0.1952
# Epoch 16/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9549 - loss: 0.1204 - val_accuracy: 0.9298 - val_loss: 0.2110
# Epoch 17/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9564 - loss: 0.1163 - val_accuracy: 0.9309 - val_loss: 0.2081
# Epoch 18/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9585 - loss: 0.1099 - val_accuracy: 0.9312 - val_loss: 0.2042
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9306 - loss: 0.2040
# Test Accuracy (Adam, Batch 128): 0.9312
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# ====================
# Training Case: SGD w/ Momentum, Batch 64
# ====================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.7707 - loss: 0.6577 - val_accuracy: 0.8731 - val_loss: 0.3377
# Epoch 2/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8822 - loss: 0.3210 - val_accuracy: 0.8736 - val_loss: 0.3465
# Epoch 3/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.8990 - loss: 0.2754 - val_accuracy: 0.9104 - val_loss: 0.2454
# Epoch 4/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9069 - loss: 0.2494 - val_accuracy: 0.9164 - val_loss: 0.2298
# Epoch 5/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9170 - loss: 0.2280 - val_accuracy: 0.9146 - val_loss: 0.2291
# Epoch 6/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9192 - loss: 0.2180 - val_accuracy: 0.9124 - val_loss: 0.2388
# Epoch 7/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9231 - loss: 0.2080 - val_accuracy: 0.9245 - val_loss: 0.2080
# Epoch 8/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9255 - loss: 0.2002 - val_accuracy: 0.9260 - val_loss: 0.2045
# Epoch 9/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9315 - loss: 0.1866 - val_accuracy: 0.9252 - val_loss: 0.2016
# Epoch 10/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9329 - loss: 0.1804 - val_accuracy: 0.9261 - val_loss: 0.2034
# Epoch 11/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9377 - loss: 0.1682 - val_accuracy: 0.9144 - val_loss: 0.2327
# Epoch 12/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9388 - loss: 0.1643 - val_accuracy: 0.9263 - val_loss: 0.1991
# Epoch 13/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9383 - loss: 0.1621 - val_accuracy: 0.9241 - val_loss: 0.2067
# Epoch 14/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9420 - loss: 0.1556 - val_accuracy: 0.9302 - val_loss: 0.1978
# Epoch 15/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9436 - loss: 0.1525 - val_accuracy: 0.9283 - val_loss: 0.2003
# Epoch 16/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9446 - loss: 0.1471 - val_accuracy: 0.9324 - val_loss: 0.1990
# Epoch 17/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9474 - loss: 0.1419 - val_accuracy: 0.9329 - val_loss: 0.1975
# Epoch 18/18
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9504 - loss: 0.1342 - val_accuracy: 0.9334 - val_loss: 0.1968
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9350 - loss: 0.1969
# Test Accuracy (SGD w/ Momentum, Batch 64): 0.9334
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# ====================
# Training Case: SGD w/ Momentum, Batch 128
# ====================
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.7464 - loss: 0.7276 - val_accuracy: 0.7392 - val_loss: 0.7075
# Epoch 2/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8726 - loss: 0.3446 - val_accuracy: 0.8867 - val_loss: 0.2991
# Epoch 3/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.8927 - loss: 0.2937 - val_accuracy: 0.8708 - val_loss: 0.3611
# Epoch 4/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9030 - loss: 0.2620 - val_accuracy: 0.9012 - val_loss: 0.2773
# Epoch 5/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9106 - loss: 0.2418 - val_accuracy: 0.9081 - val_loss: 0.2527
# Epoch 6/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9138 - loss: 0.2296 - val_accuracy: 0.8989 - val_loss: 0.2663
# Epoch 7/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9203 - loss: 0.2168 - val_accuracy: 0.9160 - val_loss: 0.2311
# Epoch 8/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9209 - loss: 0.2145 - val_accuracy: 0.9004 - val_loss: 0.2762
# Epoch 9/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9245 - loss: 0.2006 - val_accuracy: 0.9220 - val_loss: 0.2212
# Epoch 10/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9305 - loss: 0.1872 - val_accuracy: 0.9217 - val_loss: 0.2204
# Epoch 11/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9326 - loss: 0.1818 - val_accuracy: 0.9207 - val_loss: 0.2161
# Epoch 12/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9344 - loss: 0.1764 - val_accuracy: 0.9178 - val_loss: 0.2310
# Epoch 13/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9366 - loss: 0.1704 - val_accuracy: 0.9158 - val_loss: 0.2336
# Epoch 14/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9413 - loss: 0.1615 - val_accuracy: 0.9269 - val_loss: 0.2042
# Epoch 15/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9407 - loss: 0.1589 - val_accuracy: 0.9312 - val_loss: 0.1945
# Epoch 16/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9414 - loss: 0.1593 - val_accuracy: 0.9240 - val_loss: 0.2144
# Epoch 17/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9437 - loss: 0.1538 - val_accuracy: 0.9291 - val_loss: 0.1983
# Epoch 18/18
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9438 - loss: 0.1485 - val_accuracy: 0.9255 - val_loss: 0.2134
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9278 - loss: 0.2214
# Test Accuracy (SGD w/ Momentum, Batch 128): 0.9255
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Load Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# Normalize images to [0,1] range
x_train, x_test = x_train / 255.0, x_test / 255.0

# Reshape for CNN (Adding channel dimension)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# CNN Model with deeper architecture
model = keras.Sequential([
        layers.Conv2D(32, (3,3), padding='same', activation=None, input_shape=(28,28,1)),
        layers.Activation('relu'),
        layers.BatchNormalization(),

        layers.Conv2D(32, (3,3), padding='same', activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.2),

        layers.Conv2D(64, (3,3), padding='same', activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),

        layers.Conv2D(64, (3,3), padding='same', activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.2),

        layers.Conv2D(128, (3,3), padding='same', activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.2),

        layers.Flatten(),
        layers.Dense(512, activation=None),
        layers.Activation('relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.2),

        layers.Dense(10, activation='softmax')
    ])


# Compile the model with reduced learning rate
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0005),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model with increased batch size
history = model.fit(x_train, y_train, epochs=130, batch_size=64, validation_data=(x_test, y_test))

# Evaluate test accuracy
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")

# Plot Accuracy & Loss Curves
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 25s 15ms/step - accuracy: 0.7551 - loss: 0.7009 - val_accuracy: 0.8757 - val_loss: 0.3447
# Epoch 2/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8756 - loss: 0.3350 - val_accuracy: 0.8960 - val_loss: 0.2801
# Epoch 3/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8928 - loss: 0.2860 - val_accuracy: 0.9124 - val_loss: 0.2436
# Epoch 4/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9108 - loss: 0.2455 - val_accuracy: 0.9159 - val_loss: 0.2298
# Epoch 5/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9176 - loss: 0.2253 - val_accuracy: 0.9179 - val_loss: 0.2291
# Epoch 6/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9215 - loss: 0.2103 - val_accuracy: 0.9111 - val_loss: 0.2432
# Epoch 7/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9278 - loss: 0.1944 - val_accuracy: 0.9180 - val_loss: 0.2214
# Epoch 8/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9316 - loss: 0.1849 - val_accuracy: 0.9286 - val_loss: 0.2021
# Epoch 9/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9357 - loss: 0.1742 - val_accuracy: 0.9292 - val_loss: 0.2026
# Epoch 10/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9389 - loss: 0.1618 - val_accuracy: 0.9274 - val_loss: 0.2043
# Epoch 11/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9410 - loss: 0.1570 - val_accuracy: 0.9284 - val_loss: 0.2017
# Epoch 12/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9459 - loss: 0.1427 - val_accuracy: 0.9298 - val_loss: 0.1945
# Epoch 13/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9491 - loss: 0.1371 - val_accuracy: 0.9313 - val_loss: 0.1997
# Epoch 14/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9477 - loss: 0.1362 - val_accuracy: 0.9350 - val_loss: 0.1862
# Epoch 15/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9527 - loss: 0.1259 - val_accuracy: 0.9322 - val_loss: 0.2011
# Epoch 16/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9565 - loss: 0.1185 - val_accuracy: 0.9369 - val_loss: 0.1913
# Epoch 17/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9580 - loss: 0.1107 - val_accuracy: 0.9353 - val_loss: 0.2001
# Epoch 18/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9588 - loss: 0.1076 - val_accuracy: 0.9319 - val_loss: 0.2046
# Epoch 19/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9622 - loss: 0.1007 - val_accuracy: 0.9346 - val_loss: 0.2076
# Epoch 20/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9619 - loss: 0.1015 - val_accuracy: 0.9356 - val_loss: 0.2088
# Epoch 21/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9618 - loss: 0.0978 - val_accuracy: 0.9362 - val_loss: 0.2186
# Epoch 22/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9644 - loss: 0.0933 - val_accuracy: 0.9389 - val_loss: 0.2026
# Epoch 23/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9685 - loss: 0.0850 - val_accuracy: 0.9377 - val_loss: 0.2013
# Epoch 24/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9692 - loss: 0.0830 - val_accuracy: 0.9381 - val_loss: 0.2117
# Epoch 25/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9703 - loss: 0.0794 - val_accuracy: 0.9356 - val_loss: 0.2092
# Epoch 26/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9716 - loss: 0.0743 - val_accuracy: 0.9347 - val_loss: 0.2246
# Epoch 27/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9702 - loss: 0.0778 - val_accuracy: 0.9383 - val_loss: 0.2167
# Epoch 28/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9739 - loss: 0.0735 - val_accuracy: 0.9366 - val_loss: 0.2295
# Epoch 29/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9735 - loss: 0.0712 - val_accuracy: 0.9398 - val_loss: 0.2209
# Epoch 30/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9753 - loss: 0.0658 - val_accuracy: 0.9388 - val_loss: 0.2269
# Epoch 31/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9747 - loss: 0.0675 - val_accuracy: 0.9359 - val_loss: 0.2443
# Epoch 32/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9759 - loss: 0.0641 - val_accuracy: 0.9375 - val_loss: 0.2269
# Epoch 33/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9761 - loss: 0.0645 - val_accuracy: 0.9366 - val_loss: 0.2412
# Epoch 34/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9774 - loss: 0.0616 - val_accuracy: 0.9388 - val_loss: 0.2359
# Epoch 35/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9789 - loss: 0.0578 - val_accuracy: 0.9375 - val_loss: 0.2321
# Epoch 36/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9786 - loss: 0.0579 - val_accuracy: 0.9390 - val_loss: 0.2410
# Epoch 37/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9789 - loss: 0.0555 - val_accuracy: 0.9397 - val_loss: 0.2328
# Epoch 38/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9798 - loss: 0.0525 - val_accuracy: 0.9403 - val_loss: 0.2356
# Epoch 39/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9802 - loss: 0.0537 - val_accuracy: 0.9396 - val_loss: 0.2358
# Epoch 40/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9812 - loss: 0.0515 - val_accuracy: 0.9391 - val_loss: 0.2450
# Epoch 41/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9812 - loss: 0.0512 - val_accuracy: 0.9386 - val_loss: 0.2421
# Epoch 42/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9803 - loss: 0.0517 - val_accuracy: 0.9383 - val_loss: 0.2521
# Epoch 43/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9819 - loss: 0.0492 - val_accuracy: 0.9397 - val_loss: 0.2506
# Epoch 44/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9819 - loss: 0.0499 - val_accuracy: 0.9381 - val_loss: 0.2617
# Epoch 45/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9831 - loss: 0.0453 - val_accuracy: 0.9412 - val_loss: 0.2456
# Epoch 46/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9840 - loss: 0.0426 - val_accuracy: 0.9395 - val_loss: 0.2587
# Epoch 47/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9840 - loss: 0.0422 - val_accuracy: 0.9362 - val_loss: 0.2808
# Epoch 48/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9830 - loss: 0.0464 - val_accuracy: 0.9397 - val_loss: 0.2623
# Epoch 49/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9844 - loss: 0.0434 - val_accuracy: 0.9399 - val_loss: 0.2678
# Epoch 50/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9849 - loss: 0.0409 - val_accuracy: 0.9401 - val_loss: 0.2688
# Epoch 51/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9856 - loss: 0.0408 - val_accuracy: 0.9369 - val_loss: 0.2845
# Epoch 52/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9842 - loss: 0.0438 - val_accuracy: 0.9404 - val_loss: 0.2634
# Epoch 53/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9849 - loss: 0.0406 - val_accuracy: 0.9400 - val_loss: 0.2743
# Epoch 54/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9860 - loss: 0.0372 - val_accuracy: 0.9390 - val_loss: 0.2743
# Epoch 55/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9860 - loss: 0.0385 - val_accuracy: 0.9411 - val_loss: 0.2811
# Epoch 56/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9852 - loss: 0.0407 - val_accuracy: 0.9401 - val_loss: 0.2619
# Epoch 57/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9883 - loss: 0.0333 - val_accuracy: 0.9423 - val_loss: 0.2715
# Epoch 58/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9866 - loss: 0.0360 - val_accuracy: 0.9415 - val_loss: 0.2708
# Epoch 59/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9867 - loss: 0.0372 - val_accuracy: 0.9408 - val_loss: 0.2757
# Epoch 60/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9866 - loss: 0.0370 - val_accuracy: 0.9399 - val_loss: 0.2719
# Epoch 61/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9872 - loss: 0.0357 - val_accuracy: 0.9401 - val_loss: 0.2838
# Epoch 62/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9871 - loss: 0.0345 - val_accuracy: 0.9406 - val_loss: 0.2826
# Epoch 63/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9884 - loss: 0.0321 - val_accuracy: 0.9412 - val_loss: 0.2868
# Epoch 64/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9877 - loss: 0.0325 - val_accuracy: 0.9413 - val_loss: 0.2810
# Epoch 65/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9868 - loss: 0.0338 - val_accuracy: 0.9385 - val_loss: 0.2915
# Epoch 66/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9900 - loss: 0.0285 - val_accuracy: 0.9411 - val_loss: 0.2950
# Epoch 67/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9892 - loss: 0.0302 - val_accuracy: 0.9392 - val_loss: 0.2896
# Epoch 68/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9891 - loss: 0.0296 - val_accuracy: 0.9423 - val_loss: 0.2770
# Epoch 69/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9886 - loss: 0.0311 - val_accuracy: 0.9404 - val_loss: 0.3029
# Epoch 70/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9900 - loss: 0.0271 - val_accuracy: 0.9380 - val_loss: 0.3098
# Epoch 71/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9883 - loss: 0.0315 - val_accuracy: 0.9384 - val_loss: 0.3125
# Epoch 72/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9887 - loss: 0.0307 - val_accuracy: 0.9381 - val_loss: 0.3112
# Epoch 73/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9888 - loss: 0.0312 - val_accuracy: 0.9419 - val_loss: 0.2837
# Epoch 74/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9897 - loss: 0.0291 - val_accuracy: 0.9411 - val_loss: 0.2959
# Epoch 75/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9896 - loss: 0.0295 - val_accuracy: 0.9419 - val_loss: 0.3014
# Epoch 76/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9882 - loss: 0.0332 - val_accuracy: 0.9405 - val_loss: 0.2967
# Epoch 77/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9890 - loss: 0.0301 - val_accuracy: 0.9415 - val_loss: 0.2884
# Epoch 78/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9901 - loss: 0.0282 - val_accuracy: 0.9414 - val_loss: 0.2857
# Epoch 79/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9904 - loss: 0.0264 - val_accuracy: 0.9404 - val_loss: 0.3028
# Epoch 80/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9906 - loss: 0.0262 - val_accuracy: 0.9380 - val_loss: 0.3054
# Epoch 81/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9898 - loss: 0.0275 - val_accuracy: 0.9414 - val_loss: 0.3073
# Epoch 82/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9896 - loss: 0.0278 - val_accuracy: 0.9414 - val_loss: 0.2861
# Epoch 83/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9898 - loss: 0.0274 - val_accuracy: 0.9415 - val_loss: 0.2927
# Epoch 84/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9910 - loss: 0.0248 - val_accuracy: 0.9450 - val_loss: 0.2921
# Epoch 85/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9904 - loss: 0.0272 - val_accuracy: 0.9432 - val_loss: 0.2883
# Epoch 86/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9915 - loss: 0.0241 - val_accuracy: 0.9409 - val_loss: 0.2965
# Epoch 87/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9910 - loss: 0.0241 - val_accuracy: 0.9408 - val_loss: 0.2899
# Epoch 88/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9904 - loss: 0.0260 - val_accuracy: 0.9421 - val_loss: 0.2971
# Epoch 89/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9915 - loss: 0.0228 - val_accuracy: 0.9414 - val_loss: 0.3108
# Epoch 90/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9911 - loss: 0.0247 - val_accuracy: 0.9379 - val_loss: 0.3162
# Epoch 91/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9905 - loss: 0.0251 - val_accuracy: 0.9402 - val_loss: 0.3036
# Epoch 92/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9903 - loss: 0.0279 - val_accuracy: 0.9422 - val_loss: 0.3093
# Epoch 93/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9908 - loss: 0.0235 - val_accuracy: 0.9430 - val_loss: 0.3100
# Epoch 94/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9905 - loss: 0.0238 - val_accuracy: 0.9396 - val_loss: 0.3091
# Epoch 95/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9909 - loss: 0.0253 - val_accuracy: 0.9421 - val_loss: 0.3176
# Epoch 96/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9915 - loss: 0.0240 - val_accuracy: 0.9409 - val_loss: 0.3107
# Epoch 97/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9920 - loss: 0.0222 - val_accuracy: 0.9402 - val_loss: 0.3127
# Epoch 98/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9909 - loss: 0.0242 - val_accuracy: 0.9401 - val_loss: 0.3155
# Epoch 99/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9923 - loss: 0.0217 - val_accuracy: 0.9405 - val_loss: 0.3231
# Epoch 100/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9925 - loss: 0.0207 - val_accuracy: 0.9386 - val_loss: 0.3140
# Epoch 101/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9921 - loss: 0.0210 - val_accuracy: 0.9400 - val_loss: 0.3300
# Epoch 102/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9921 - loss: 0.0216 - val_accuracy: 0.9403 - val_loss: 0.3346
# Epoch 103/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9917 - loss: 0.0249 - val_accuracy: 0.9414 - val_loss: 0.3120
# Epoch 104/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9924 - loss: 0.0211 - val_accuracy: 0.9396 - val_loss: 0.3250
# Epoch 105/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9924 - loss: 0.0218 - val_accuracy: 0.9412 - val_loss: 0.3167
# Epoch 106/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9921 - loss: 0.0224 - val_accuracy: 0.9404 - val_loss: 0.3253
# Epoch 107/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9922 - loss: 0.0212 - val_accuracy: 0.9407 - val_loss: 0.3129
# Epoch 108/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9921 - loss: 0.0225 - val_accuracy: 0.9409 - val_loss: 0.3180
# Epoch 109/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9930 - loss: 0.0181 - val_accuracy: 0.9396 - val_loss: 0.3381
# Epoch 110/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9922 - loss: 0.0229 - val_accuracy: 0.9399 - val_loss: 0.3341
# Epoch 111/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9934 - loss: 0.0202 - val_accuracy: 0.9389 - val_loss: 0.3254
# Epoch 112/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9930 - loss: 0.0205 - val_accuracy: 0.9400 - val_loss: 0.3174
# Epoch 113/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9933 - loss: 0.0186 - val_accuracy: 0.9395 - val_loss: 0.3415
# Epoch 114/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9927 - loss: 0.0202 - val_accuracy: 0.9405 - val_loss: 0.3184
# Epoch 115/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9932 - loss: 0.0192 - val_accuracy: 0.9427 - val_loss: 0.3112
# Epoch 116/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9926 - loss: 0.0219 - val_accuracy: 0.9406 - val_loss: 0.3186
# Epoch 117/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9925 - loss: 0.0209 - val_accuracy: 0.9418 - val_loss: 0.3144
# Epoch 118/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9933 - loss: 0.0193 - val_accuracy: 0.9414 - val_loss: 0.3309
# Epoch 119/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9935 - loss: 0.0180 - val_accuracy: 0.9417 - val_loss: 0.3245
# Epoch 120/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9929 - loss: 0.0190 - val_accuracy: 0.9414 - val_loss: 0.3111
# Epoch 121/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9935 - loss: 0.0185 - val_accuracy: 0.9424 - val_loss: 0.3209
# Epoch 122/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9932 - loss: 0.0183 - val_accuracy: 0.9432 - val_loss: 0.3213
# Epoch 123/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9929 - loss: 0.0210 - val_accuracy: 0.9401 - val_loss: 0.3312
# Epoch 124/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9923 - loss: 0.0220 - val_accuracy: 0.9414 - val_loss: 0.3211
# Epoch 125/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9930 - loss: 0.0193 - val_accuracy: 0.9420 - val_loss: 0.3298
# Epoch 126/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9935 - loss: 0.0185 - val_accuracy: 0.9419 - val_loss: 0.3182
# Epoch 127/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9931 - loss: 0.0188 - val_accuracy: 0.9402 - val_loss: 0.3318
# Epoch 128/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9942 - loss: 0.0183 - val_accuracy: 0.9408 - val_loss: 0.3329
# Epoch 129/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9926 - loss: 0.0203 - val_accuracy: 0.9401 - val_loss: 0.3372
# Epoch 130/130
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9937 - loss: 0.0186 - val_accuracy: 0.9429 - val_loss: 0.3314
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9424 - loss: 0.3450
# Test Accuracy: 0.9429
